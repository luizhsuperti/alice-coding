# %%
from cida.interfaces.data_interactor import DataInteractor

import numpy as np
import pandas as pd
import sqlalchemy
# Import date and timedelta class


#request 
import requests
di = DataInteractor()


#import warnings
import warnings
warnings.filterwarnings('ignore')
import os
import collections

#time packages
import datetime as dt

from cida.interfaces.model import StaggDiD

# %% [markdown]
# ## 1. extract

# %%
df_fp = di.redshift.run_str_query(
    query="""
    SELECT
    
"""
)

# %%
df = pd.read_csv(os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + '/data/external/cid_care_cost_did_calc_df.csv')
df['diseases_'] = df['diseases_sev'].str.split(';')
df2 = df.explode('diseases_')
df2['cid_'] = df2['diseases_'].apply(lambda x: str(x).strip()[0:3])
df3 = df2[['member_internal_code','calendar_date', 'cid_']].drop_duplicates()

# %%
df_row = pd.get_dummies(df3['cid_'], prefix = 'cid')
df_row_2 = df3[['member_internal_code', 'calendar_date']].merge(df_row, how = 'inner', left_index=True, right_index=True)
df_row_3 = df_row_2.groupby(['member_internal_code', 'calendar_date']).max().reset_index()
df_row_3.sort_values(by=['member_internal_code', 'calendar_date'], inplace=True)
#create a cid filter
df_row_3.drop(columns = 'cid_nan', inplace = True)
cids_cols = [col for col in df_row_3 if col.startswith('cid_')]
df_row_3[cids_cols] = df_row_3[cids_cols].apply(pd.to_numeric).fillna(0)

# %%
df_filled = df.merge(
                    pd.get_dummies(df.current_state, prefix = 'uf'),how = 'inner', left_index=True, right_index=True).merge(
                        pd.get_dummies(df.current_city, prefix = 'city'),how = 'inner', left_index=True, right_index=True).drop(columns=['current_state', 'current_city'])
df_filled['is_male'] = np.where(df_filled['current_sex']=='MALE',1,0)
df_filled['is_trans'] = np.where(df_filled['current_sex']!=df_filled['current_gender'],1,0)
#create the base-dummies
df_filled.drop(columns=['current_gender','current_sex','city_São Paulo', 'uf_SP',
                        'diseases_sev','tds_cost', 'exam_cost', 'consulta_cost',
                        'internacao_proced_cost', 'er_cost',
                        'alice_therapy_cost', 'other_costs'], inplace=True)
df_filled.drop(columns=['diseases_'], inplace=True)

base_covariates_list = df_filled.drop(columns = ['member_internal_code', 'calendar_date', 'mth_order','total_n_mth', 'total_care_cost']).columns.to_list()
core_covariates = ['member_age', 'is_pitaya', 'is_male']

# %% [markdown]
# merge bases

# %%
ml_df = df_filled.merge(df_row_3, how = 'inner', left_on=['member_internal_code', 'calendar_date'], right_on = ['member_internal_code', 'calendar_date'])

#adjust variables
ml_df['n_total_cids'] = ml_df[cids_cols].sum(axis=1)
ml_df['ref_mth'] = (pd.to_datetime(ml_df['calendar_date']).dt.to_period('M') -   pd.to_datetime(['1970-01-31']).to_period('M')).apply(lambda x: x.n)

#entry-calendar date
ml_df['v1'] = np.where(ml_df['mth_order']==1, ml_df['ref_mth'], np.nan)
ml_df = ml_df.merge(ml_df.groupby(['member_internal_code'])['v1'].min().rename('ref_mth_entrance_group'), how = 'inner', left_on = 'member_internal_code', right_index = True)
ml_df['ref_mth_entrance_group'] = ml_df['ref_mth_entrance_group'].astype('Int64')
ml_df.drop(columns = ['v1'], inplace = True)

# %%
ml_df_calendar_base = ml_df[['member_internal_code','calendar_date','mth_order','ref_mth', 'ref_mth_entrance_group']]
base_df = ml_df
accountable_cids = base_df.groupby('member_internal_code')[cids_cols].min().drop_duplicates().sum(axis=0).sort_values(ascending=False)
accountable_cids = accountable_cids[accountable_cids>=10].index.to_list()

# %% [markdown]
# # 2. Train

# %%
from sklearn.linear_model import LogisticRegression
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

logit = LogisticRegression()

# define pipeline 1
over = SMOTE(sampling_strategy=0.1)
under = RandomUnderSampler(sampling_strategy=0.5)
steps = [('o', over), ('u', under)]
pipeline_compl_ = Pipeline(steps=steps)


# define pipeline 2
under = RandomUnderSampler(sampling_strategy=0.5)
steps = [('u', under)]
pipeline_under_ = Pipeline(steps=steps)


dd = StaggDiD

# %%
entry_list_cids = []
diagnosed_list  = []
results_df = pd.DataFrame()
for cid in accountable_cids:
    #cid_list not including the cid
    cid_list = [c for c in cids_cols if c!=cid]

    temp_df = pd.concat([ml_df_calendar_base, base_df[cid]], axis = 1)
    temp_df.sort_values(by = ['member_internal_code', 'calendar_date'], inplace = True)
    #
    lag_name = cid + '_lag_1'
    temp_df = pd.concat([temp_df,temp_df.groupby(['member_internal_code'])[cid].shift(1).rename(lag_name)], axis = 1)
    temp_df.sort_values(by = ['member_internal_code', 'calendar_date'], inplace = True)
    #
    entry_name = 'entry_' + cid
    diag_name = 'diag_' + cid
    #
    temp_df['v1'] = np.where((temp_df[cid]==1) & (temp_df['mth_order']==1), 1, 0)
    temp_df['ind_diag_mth'] = np.where((temp_df[cid]==1) & (temp_df[lag_name]!=1) & (temp_df['mth_order']>=2), 1, 0)
    temp_df = temp_df.merge(temp_df.groupby(['member_internal_code'])['v1'].max().rename(entry_name), how = 'inner', left_on = 'member_internal_code', right_index = True)
    temp_df = temp_df.merge(temp_df.groupby(['member_internal_code'])['ind_diag_mth'].max().rename(diag_name), how = 'inner', left_on = 'member_internal_code', right_index = True)
    temp_df.drop(columns = ['v1',lag_name], inplace = True)

    if temp_df[entry_name].mean()>0:
        print('current cid:', entry_name)
        print(' dataframe creation pt2')
        treat_group_mths = temp_df[temp_df[entry_name]==1]['ref_mth_entrance_group'].unique()
        control_group = temp_df[(temp_df['ref_mth_entrance_group'].isin(treat_group_mths)) & (temp_df[entry_name]==0) & (temp_df[entry_name]==0)]
        total_df = pd.concat([temp_df[temp_df[entry_name]==1], control_group], axis = 0)
        df = base_df[base_covariates_list + cid_list + ['total_care_cost'] + ['member_internal_code','mth_order', 'ref_mth_entrance_group']].merge(total_df[[entry_name] + ['ind_diag_mth']], how = 'inner', left_index = True, right_index = True)
        df = df.merge(df[df['ind_diag_mth']==1].groupby('member_internal_code')['mth_order'].max().rename('diag_mth_order'), how = 'left', left_on = 'member_internal_code', right_index = True)

        #keep those that were NOT diagnosed afterwards
        df = df[(df['diag_mth_order'].isna())|(df['diag_mth_order']==1)]

        X0 = df[df['mth_order']==1][base_covariates_list + cid_list]
        y0 = df[df['mth_order']==1][entry_name]
        
        print(' Propensity score matching w/ SMOTE and resampling')
        if (y0.mean()>=0.1) & (y0.value_counts()[1]>=10):
            X, y = pipeline_under_.fit_resample(X0, y0)

        elif (y0.mean()<0.1) & (y0.value_counts()[1]>=10):
            X, y = pipeline_compl_.fit_resample(X0, y0)

        else:
            print('     not enough samples to estimate propensity score')
        clf = logit.fit(X,y)
        pre_treat = clf.predict(df[df['mth_order']==1][base_covariates_list + cid_list])


        print(' dataframe creation pt2')
        df.loc[df['mth_order']==1, 'pre_treat'] = pre_treat
        df = df.merge(df.groupby(['member_internal_code'])['pre_treat'].max().rename('pre_treat_max'), how = 'inner', left_on = 'member_internal_code', right_index = True)
        df['treat'] = np.where(df[entry_name]==1, 1, 0)
        df.loc[(df['treat']==0) & (df['pre_treat_max']==0), 'treat'] = np.nan

        month_list = df[df[entry_name]==1]['ref_mth_entrance_group'].unique()
        new_ml_df = df[df['ref_mth_entrance_group'].isin(month_list) & (df['treat'].notna())][['member_internal_code','mth_order','ref_mth_entrance_group','treat', 'total_care_cost'] + core_covariates]
        #let's just maintain reference mths with overlapp of treatment and control:

        new_ml_df = new_ml_df.merge(new_ml_df.groupby(['ref_mth_entrance_group'])['treat'].mean().rename('max_treat_pp'), how = 'inner', left_on='ref_mth_entrance_group', right_index = True)
        new_ml_df = new_ml_df[(new_ml_df['max_treat_pp']>0) & (new_ml_df['max_treat_pp']<1)]

        print(' dataframe creation pt3: event analysis')
        new_df = pd.DataFrame()
        for pr_mth in new_ml_df['ref_mth_entrance_group'].unique():
            treat_df = new_ml_df[(new_ml_df['ref_mth_entrance_group']==pr_mth) & (new_ml_df['treat']==1)]
            treat_df['ev_an_mth'] = treat_df['mth_order'] - 1
            treat_df['id_group'] = treat_df['member_internal_code'].astype(str) 
            #
            control_df = new_ml_df[(new_ml_df['ref_mth_entrance_group']==pr_mth) & (new_ml_df['treat']==0)]
            control_df['ev_an_mth'] = control_df['mth_order'] - 1
            control_df['id_group'] = control_df['member_internal_code'].astype(str) 

            new_df = pd.concat([new_df,treat_df, control_df], axis = 0)

        final_ml_df = new_df.sort_values(['id_group','ev_an_mth'])
        final_ml_df.drop(columns = ['mth_order', 'member_internal_code'], inplace = True)

        print(' att_calculus')
        att_df = dd.att(final_ml_df, 'id_group', 'treat', 'total_care_cost', 'ev_an_mth', 0, 6)

        att_df['cid'] = cid[4:7]
        att_df['analysis_type'] = 'on_entry' 
        results_df = pd.concat([results_df, att_df], axis = 0)
        entry_list_cids.append(entry_name)

        try:
            del df, new_ml_df, new_df, final_ml_df, att_df, X0, y0,pre_treat,control_df,treat_df, X, y
        except:
            del df, new_ml_df, new_df, final_ml_df, att_df, X0, y0,pre_treat

    if temp_df[diag_name].mean()>0:
        print('current cid:', diag_name)
        #DF to estimate variables
        print(' dataframe creation pt1')

        treat_group_mths = temp_df[temp_df[diag_name]==1]['ref_mth_entrance_group'].unique()
        control_group = temp_df[(temp_df['ref_mth_entrance_group'].isin(treat_group_mths)) & (temp_df[diag_name]==0) & (temp_df[diag_name]==0)]
        total_df = pd.concat([temp_df[temp_df[diag_name]==1], control_group], axis = 0)
        df = base_df[base_covariates_list + cid_list + ['total_care_cost'] + ['member_internal_code','mth_order', 'ref_mth_entrance_group']].merge(total_df[[diag_name] + ['ind_diag_mth']], how = 'inner', left_index = True, right_index = True)
        df = df.merge(df[df['ind_diag_mth']==1].groupby('member_internal_code')['mth_order'].max().rename('diag_mth_order'), how = 'left', left_on = 'member_internal_code', right_index = True)

        X0 = df[df['mth_order']==1][base_covariates_list + cid_list]
        y0 = df[df['mth_order']==1][diag_name]

        print(' Propensity score matching w/ SMOTE and resampling')
        if (y0.mean()>=0.1) & (y0.value_counts()[1]>=10):
            X, y = pipeline_under_.fit_resample(X0, y0)

        elif (y0.mean()<0.1) & (y0.value_counts()[1]>=10):
            X, y = pipeline_compl_.fit_resample(X0, y0)

        else:
            print('     not enough samples to estimate propensity score')
            continue
        clf = logit.fit(X,y)
        pre_treat = clf.predict(df[df['mth_order']==1][base_covariates_list + cid_list])

        print(' dataframe creation pt2')
        df.loc[df['mth_order']==1, 'pre_treat'] = pre_treat # treatment allocation associated with the first month, as an output of the logit-ridge model
        df = df.merge(df.groupby(['member_internal_code'])['pre_treat'].max().rename('pre_treat_max'), how = 'inner', left_on = 'member_internal_code', right_index = True) #we need to keep the treatment allocation associated with the first month, to all of the other months 
        df['treat'] = np.where(df[diag_name]==1, 1, 0) #now to associate the cid in question to the 'treatment' variable
        df.loc[(df['treat']==0) & (df['pre_treat_max']==0), 'treat'] = np.nan #the others obs. that failed the logit (ie, =0) will not be considered

        month_list = df[df[diag_name]==1]['ref_mth_entrance_group'].unique()
        new_ml_df = df[df['ref_mth_entrance_group'].isin(month_list) & (df['treat'].notna())][['member_internal_code','mth_order','ref_mth_entrance_group','ind_diag_mth','diag_mth_order','treat', 'total_care_cost'] + core_covariates]
        #let's just maintain reference mths with overlapp of treatment and control:

        new_ml_df = new_ml_df.merge(new_ml_df.groupby(['ref_mth_entrance_group'])['treat'].mean().rename('max_treat_pp'), how = 'inner', left_on='ref_mth_entrance_group', right_index = True)
        new_ml_df = new_ml_df[(new_ml_df['max_treat_pp']>0) & (new_ml_df['max_treat_pp']<1)]
        print(' dataframe creation pt3: event analysis')
        new_df = pd.DataFrame()
        for pr_mth in new_ml_df['ref_mth_entrance_group'].unique():
            diag_months = new_ml_df[(new_ml_df['ind_diag_mth']==1) & (new_ml_df['ref_mth_entrance_group']==pr_mth)]['diag_mth_order'].unique()
            #print(pr_mth, diag_months)
            for mth in diag_months:
                treat_df = new_ml_df[(new_ml_df['ref_mth_entrance_group']==pr_mth) & (new_ml_df['treat']==1) & (new_ml_df['diag_mth_order']==mth)]
                treat_df['ev_an_mth'] = treat_df['mth_order'] - mth
                treat_df = treat_df.merge(treat_df.groupby('member_internal_code')['mth_order'].min().rename('min_mth_order'),how = 'inner', left_on='member_internal_code', right_index = True)
                treat_df = treat_df.merge(treat_df.groupby('member_internal_code')['ev_an_mth'].min().rename('min_ev_an_mth'),how = 'inner', left_on='member_internal_code', right_index = True)
                treat_df['id_group'] = treat_df['member_internal_code'].astype(str) + '_' + treat_df['min_ev_an_mth'].astype(str) + '_' + treat_df['min_mth_order'].astype(str)        
                treat_df.drop(columns = ['min_mth_order', 'min_ev_an_mth'], inplace = True)
                #
                control_df = new_ml_df[(new_ml_df['ref_mth_entrance_group']==pr_mth) & (new_ml_df['treat']==0)]
                control_df['ev_an_mth'] = control_df['mth_order'] - mth
                control_df = control_df.merge(control_df.groupby('member_internal_code')['mth_order'].min().rename('min_mth_order'),how = 'inner', left_on='member_internal_code', right_index = True)
                control_df = control_df.merge(control_df.groupby('member_internal_code')['ev_an_mth'].min().rename('min_ev_an_mth'),how = 'inner', left_on='member_internal_code', right_index = True)
                control_df['id_group'] = control_df['member_internal_code'].astype(str) + '_' + control_df['min_ev_an_mth'].astype(str) + '_' + control_df['min_mth_order'].astype(str)
                control_df.drop(columns = ['min_mth_order', 'min_ev_an_mth'], inplace = True)

                new_df = pd.concat([new_df,treat_df, control_df], axis = 0)

        final_ml_df = new_df.sort_values(['id_group','ev_an_mth'])
        final_ml_df.drop(columns = ['mth_order', 'diag_mth_order', 'ind_diag_mth', 'member_internal_code'], inplace = True)

        #     
        print(' att_calculus')
        att_df = dd.att(final_ml_df, 'id_group', 'treat', 'total_care_cost', 'ev_an_mth', -3, 6)

        att_df['cid'] = cid[4:7]
        att_df['analysis_type'] = 'after_entry' 
        results_df = pd.concat([results_df, att_df], axis = 0)
        diagnosed_list.append(diag_name)

        #conditional deletion
        try:
            del df, new_ml_df, new_df, final_ml_df, att_df, X0, y0,pre_treat,control_df,treat_df, X, y
        except:
            del df, new_ml_df, new_df, final_ml_df, att_df, X0, y0,pre_treat
# Out:
# current cid: entry_cid_H52
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_H52
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_F41
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_F41
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_E66
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_E66
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_F32
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_F32
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_J30
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_J30
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_K29
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_K29
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_Z72
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_Z72
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_J34
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_J34
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_G47
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_G47
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_G43
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_G43
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_K21
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_K21
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_J45
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_J45
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_P01
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_P01
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_E28
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_E28
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_E03
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_E03
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_N20
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_N20
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_M54
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_M54
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_I84
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_I84
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_M23
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_M23
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_L70
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_L70
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_F33
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_F33
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_J35
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_J35
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_R74
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_R74
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_Z44
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_Z44
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_N63
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_N63
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_P74
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_P74
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_E78
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_E78
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_M41
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_M41
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_J32
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_J32
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_B97
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_B97
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_S93
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_S93
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_I10
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_I10
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_J31
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_J31
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_F90
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_F90
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_T83
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_T83
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_U07
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_U07
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_N47
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_N47
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_N80
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_N80
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_Z32
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_Z32
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_K30
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_K30
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_E07
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_E07
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_I83
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_I83
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_N94
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_N94
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_Z97
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_Z97
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_F51
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_F51
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_M51
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_M51
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_F50
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_F50
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_P03
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_P03
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_F31
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_F31
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_Z96
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_Z96
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_M75
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_M75
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_K07
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_K07
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_E73
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_E73
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_D25
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_D25
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_L20
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_L20
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_K59
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_K59
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_M22
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_M22
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_J42
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_J42
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_N83
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_N83
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_D50
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_D50
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_K76
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_K76
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_H18
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_H18
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_R63
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_R63
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_L64
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_L64
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_K60
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_K60
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_Z80
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_Z80
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_G44
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_G44
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_N39
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_N39
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_E55
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_E55
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_L21
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_L21
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_K42
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_K42
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_K20
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_K20
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_N92
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_N92
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_Z82
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_Z82
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_N01
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_N01
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_T93
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_T93
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_W78
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_W78
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_M79
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_M79
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_N95
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_N95
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_T82
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_T82
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_E06
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_E06
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_K40
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_K40
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_T91
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_T91
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_R05
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_R05
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_R73
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_R73
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_L65
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_L65
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_E53
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_E53
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_Z30
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_Z30
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_F60
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_F60
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_F52
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_F52
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_A98
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_A98
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_B37
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_B37
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_R10
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_R10
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_T78
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_T78
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_F43
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_F43
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_Z73
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_Z73
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_S83
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_S83
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_H91
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_H91
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_G40
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_G40
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_D02
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_D02
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_D01
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_D01
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_K82
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_K82
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_B24
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_B24
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_M94
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_M94
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_L05
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_L05
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_A04
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_A04
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_I87
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_I87
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_K80
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_K80
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_L30
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_L30
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_N60
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_N60
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_F84
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_F84
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_D07
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_D07
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_G56
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_G56
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_D12
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_D12
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_M65
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_M65
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_D11
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_D11
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_S82
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_S82
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_N64
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_N64
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_Z34
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_Z34
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_A99
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_A99
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_I49
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_I49
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_L98
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_L98
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_M25
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_M25
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_L40
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_L40
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_M71
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_M71
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_L03
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_L03
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_S62
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_S62
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_I34
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_I34
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#      not enough samples to estimate propensity score
# current cid: entry_cid_W12
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_W12
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_F06
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_F06
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_L60
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_L60
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_F42
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_F42
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_K35
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_K35
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_D22
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_D22
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_K25
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_K25
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_F80
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_F80
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_H53
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_H53
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_J03
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_J03
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_N93
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_N93
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_N62
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_N62
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_R75
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_R75
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_M40
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_M40
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_T05
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_T05
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_W84
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_W84
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_X14
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_X14
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_H01
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_H01
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_Q21
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_Q21
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#      not enough samples to estimate propensity score
# current cid: entry_cid_Z41
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_Z41
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#      not enough samples to estimate propensity score
# current cid: entry_cid_A53
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_A53
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_S23
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_S23
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_K58
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_K58
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_H50
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_H50
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_D34
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_D34
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_D27
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_D27
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_N89
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_N89
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_R06
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_R06
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_L71
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_L71
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_L81
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_L81
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_M50
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_M50
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_A60
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_A60
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_H93
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_H93
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_P02
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_P02
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_D18
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_D18
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_T07
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_T07
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_J06
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_J06
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_A92
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_A92
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_F19
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_F19
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_E10
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_E10
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_R51
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_R51
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_R03
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_R03
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_R45
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_R45
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_F34
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_F34
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_I82
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_I82
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_N84
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_N84
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_R52
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_R52
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_R42
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_R42
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_D03
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_D03
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: entry_cid_X06
#  dataframe creation pt2
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus
# current cid: diag_cid_X06
#  dataframe creation pt1
#  Propensity score matching w/ SMOTE and resampling
#  dataframe creation pt2
#  dataframe creation pt3: event analysis
#  att_calculus

# %% [markdown]
# ***

# %%
#adding significant column
results_df['is_signicant'] = np.nan
results_df['after_entry_analysis_is_valid'] = np.nan

# %%
results_df.loc[(results_df['analysis_type'] == 'after_entry') & (results_df['lower_bound'] > 0)  & (results_df['time'] >= 0), 'is_signicant'] = 1
results_df.loc[(results_df['analysis_type'] == 'on_entry') & (results_df['lower_bound'] > 0)  & (results_df['time'] >= 1), 'is_signicant'] = 1

results_df = results_df.merge(results_df.groupby(['cid','analysis_type'])['is_signicant'].max().rename('v1'), how = 'inner', left_on = ['cid','analysis_type'], right_index = True)
del results_df['is_signicant']
results_df.rename(columns = {'v1':'is_signicant'}, inplace = True)
results_df['is_signicant'].fillna(0, inplace = True)

####################################
results_df.loc[(results_df['analysis_type'] == 'after_entry') & (results_df['time']< -1), 'after_entry_analysis_is_valid'] = 0
results_df.loc[(results_df['analysis_type'] == 'after_entry') & (results_df['time']< -1)  & (results_df['lower_bound'] < 0) & (results_df['upper_bound'] > 0), 'after_entry_analysis_is_valid'] = 1
results_df = results_df.merge(results_df.groupby(['cid','analysis_type'])['after_entry_analysis_is_valid'].mean().rename('v1'), how = 'inner', left_on = ['cid','analysis_type'], right_index = True)
del results_df['after_entry_analysis_is_valid']
results_df.rename(columns = {'v1':'after_entry_analysis_is_valid'}, inplace = True)
results_df['after_entry_analysis_is_valid'] = np.where(results_df['after_entry_analysis_is_valid'] < 1, 0, results_df['after_entry_analysis_is_valid'] )
results_df.loc[(results_df['analysis_type'] == 'after_entry')] ['after_entry_analysis_is_valid'].fillna(0, inplace = True)

# %%
di.redshift.insert_table(results_df, table_name='care_cost_calculator_cida_results', if_exists='replace')
# Out:
# Table care_cost_calculator_cida_results inserted successfully, with 2994 rows.
